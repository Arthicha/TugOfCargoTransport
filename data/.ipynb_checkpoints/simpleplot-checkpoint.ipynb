# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Acquisition

# %%
FILENAME = "toward_a_goal"

# %%
df = pd.read_csv(FILENAME+".csv")
print(list(df.columns))
# Out:
# ['time', 'cargo x', 'cargo y', 'cargo z', 'cargo alpha', 'cargo beta', 'cargo gamma', 'phi1', 'phi2', 'phi3', 'phi4', 'current1', 'current2', 'current3', 'current4', 'r1 x', 'r1 y', 'r1 z', 'r2 x', 'r2 y', 'r2 z', 'r3 x', 'r3 y', 'r3 z', 'r4 x', 'r4 y', 'r4 z']

# %% [markdown]
# # Plot Cargo Trajectory

# %%
# 1. Prepare data
time = df["time"].to_numpy() / 20 / 60
cargo_position = df[["cargo x", "cargo y"]].to_numpy()

# Extract key coordinates
start_x, start_y, start_z = cargo_position[0, 0], cargo_position[0, 1], time[0]
goal_x, goal_y, goal_z = cargo_position[-1, 0], cargo_position[-1, 1], time[-1]

# 2. Setup 3D plot
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111, projection="3d")

# 3. Plot trajectory line
ax.plot(
    cargo_position[:, 0],
    cargo_position[:, 1],
    time,
    color="k",
    linewidth=2,
    label="Cargo Trajectory",
)

# 4. Scatter and label START point (circle marker 'o')
ax.scatter(
    start_x,
    start_y,
    start_z,
    color="k",
    marker="o",
    s=150,
    zorder=5,
    label="Start",
)
ax.text(
    start_x,
    start_y,
    start_z,
    "  Start",
    color="k",
    fontsize=11,
    fontweight="bold",
)

# 5. Scatter and label GOAL point (star marker '*')
ax.scatter(
    goal_x,
    goal_y,
    goal_z,
    color="tab:red",
    marker="*",
    s=300,  # Increased size slightly so the star is sharp and prominent
    zorder=5,
    label="Goal",
)
ax.text(
    goal_x,
    goal_y,
    goal_z,
    "  Goal",
    color="tab:red",
    fontsize=11,
    fontweight="bold",
)

# 6. Vertical line from Goal down to z = 0
ax.plot(
    [goal_x, goal_x],
    [goal_y, goal_y],
    [goal_z, 0],
    color="tab:red",
    linestyle="--",
    linewidth=2,
    label="Goal Projection (z=0)",
)

# Optional: Add a star projection at z=0 ground level
ax.scatter(
    goal_x,
    goal_y,
    0,
    color="tab:red",
    marker="*",
    s=150,
    alpha=0.5,
)

# 7. Labels & Polish
ax.set_xlabel("X (m)")
ax.set_ylabel("Y (m)")
ax.set_zlabel("Time (min)", labelpad=12)
ax.set_title("3D Cargo Position Over Time")

ax.view_init(elev=20, azim=-85)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[118], line 91
#      87 # 7. Labels & Polish
#      88 ax.set_xlabel("X (m)")
#      89 ax.set_ylabel("Y (m)")
#      90 ax.set_zlabel("Time (min)", labelpad=12)
# ---> 91 ax.set_title("3D Cargo Position Over Time",titlepad=-10)
#      92
#      93 ax.view_init(elev=20, azim=-85)
#      94 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2937, in Axes3D.set_title(self, label, fontdict, loc, **kwargs)
#    2935 def set_title(self, label, fontdict=None, loc='center', **kwargs):
#    2936     # docstring inherited
# -> 2937     ret = super().set_title(label, fontdict=fontdict, loc=loc, **kwargs)
#    2938     (x, y) = self.title.get_position()
#    2939     self.title.set_y(0.92 * y)
#
# ...

# %%
time = df["time"].to_numpy() / 20 / 60
phis = df[["phi"+str(i+1) for i in range(4)]].to_numpy()
forces = np.clip(np.sin(phis),0,1)


# 1. Combine forces and ensure values stay in [0, 1] range for colormaps
force_blue = np.clip(forces[:, 0] + forces[:, 1], 0, 1)  # phi1 & phi2
force_red = np.clip(forces[:, 2] + forces[:, 3], 0, 1)  # phi3 & phi4

# 2. Define custom colormaps
cmap_blue = mcolors.LinearSegmentedColormap.from_list(
    "white_blue", ["white", "tab:blue"]
)
cmap_red = mcolors.LinearSegmentedColormap.from_list(
    "white_red", ["white", "tab:red"]
)

# 3. Build a 2-row RGBA matrix of shape (2, N, 4)
rgba = np.zeros((2, forces.shape[0], 4))
rgba[0] = cmap_blue(force_blue)  # Combined phi1 & phi2
rgba[1] = cmap_red(force_red)  # Combined phi3 & phi4

# 4. Plot the 2-row array with 'extent' to scale x-axis by / 20 / 60
x_max = 8000 / 20 / 60  # Maps indices 0..8000 directly to time (min)

fig, ax = plt.subplots(figsize=(10, 3))
ax.imshow(
    rgba, interpolation="nearest", aspect="auto", extent=[0, x_max, 1.5, -0.5]
)

# 5. Set y-ticks and customize label colors
ax.set_yticks([0, 1])
ax.set_yticklabels([r"$\phi_{1,2}$", r"$\phi_{3,4}$"], fontsize=15)

yticks = ax.get_yticklabels()
yticks[0].set_color("tab:blue")  # Set top label to blue
yticks[1].set_color("tab:red")  # Set bottom label to red

ax.set_xlabel("Time (min)", fontsize=15)
ax.tick_params(axis="both", labelsize=15)

ax.set_title("Self-organization Over Time\n", fontsize=15,fontweight='bold')
ax.set_xlim([1000/20/60,7000/20/60])
plt.tight_layout()
plt.show()
